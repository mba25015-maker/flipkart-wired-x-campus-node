# %%
# %cd /content
# !test -d flipkart-wired-x-campus-node/.git || git clone -q https://github.com/mba25015-maker/flipkart-wired-x-campus-node.git
# !git -C flipkart-wired-x-campus-node pull -q
# %cd /content/flipkart-wired-x-campus-node
# !pip -q install -r requirements.txt

# %% [markdown]
# ## What this notebook proves
#
# This notebook compares five dead-zone operating strategies on one common cost basis while enforcing the model's operational constraints.
#
# The `BEST` strategy is selected by the programmed decision rule rather than manually designated in the presentation.
#
# Expected result: **BEST = REPURPOSE.**

# %%
# !python3 Model/solver.py

# %% [markdown]
# ## How to read the result
#
# Compare the five rows on total dead-zone cost, residual-demand threshold, reactivation cost, lead time, and constraint feasibility.
#
# The optimum is conditional on the sourced inputs and constraints encoded in the model; changing those assumptions can change the selected strategy.
