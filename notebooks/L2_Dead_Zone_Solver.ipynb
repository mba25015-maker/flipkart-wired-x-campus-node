# %%
from pathlib import Path
import os
import subprocess
import sys

repo_name = "flipkart-wired-x-campus-node"
cwd = Path.cwd()
if (cwd / ".git").exists() and cwd.name == repo_name:
    repo = cwd
else:
    base = Path("/content") if Path("/content").exists() else cwd
    repo = base / repo_name
    if (repo / ".git").exists():
        subprocess.run(["git", "-C", str(repo), "pull", "--ff-only", "-q"], check=True)
    else:
        subprocess.run(
            ["git", "clone", "-q", "https://github.com/mba25015-maker/flipkart-wired-x-campus-node.git", str(repo)],
            check=True,
        )

os.chdir(repo)
if os.environ.get("WIRED_SKIP_INSTALL") != "1":
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
print(f"Repository ready: {repo}")
# Out:
# Repository ready: /Users/dubsey/Documents/Codex/2026-08-29/referenced-chatgpt-conversation-this-is-an/outputs/flipkart-wired-x-campus-node

# %% [markdown]
# ## What this notebook proves
#
# This notebook compares five dead-zone operating strategies on one common cost basis while enforcing the model's operating constraints.
#
# The `BEST` strategy is selected by the programmed decision rule rather than manually designated in the presentation.
#
# Expected result: **BEST = REPURPOSE.**

# %%
import subprocess, sys
subprocess.run([sys.executable, "Model/solver.py"], check=True)
# Out:
# ====================================================================================
#                           DEAD-ZONE CASH-BURN MINIMISATION
#              campus cluster dark store  |  3.5-month academic dead zone
# ====================================================================================
# minimise   dead-zone cash burn
# subject to
#    reactivation lead time >= 28 days
#                                 (semester-start demand STEPS in a 2-3 week window; capacity must be complete before day one)
#    SLA at peak            <= 27.1 min
#                                 (sla.py volume-weighted circuit model, 4x peak arrival rate, dynamic batch)
#    adjacent catchment     >= 513 orders/day
#                                 (revocation-survival site filter, risk_quadrant.post_revocation_survival)
#    store rent             == fixed
#                                 (no calendar-indexed / seasonally-abated commercial lease found in Indian practice)
#    break length           >= 7 weeks
#                                 (the academic dead zone is ~15 weeks, so wind-down is admissible)
#
# basis   residual demand r = 0% (the hole, sized as break_mode sizes it)
#         break-mode contribution/order Rs30.3 at campus AOV Rs573
#
# ------------------------------------------------------------------------------------
# STRATEGY           DEAD-ZONE  RESID DEM    REACTIVN DAYS->SVC  BEST
#                   Rs, 3.5 mo     % term          Rs      lead
# ------------------------------------------------------------------------------------
# DO_NOTHING         3,157,000      70.8%           0         0
# LABOUR_FLEX        2,159,500      59.1%     274,119        28
# COLD_RIGHTSIZE     2,121,001      57.0%     274,119        28
# SMALL_FORMAT       1,851,501      48.6%     274,119        28
# REPURPOSE*                 0      48.6%           0         0   <<< BEST
# ------------------------------------------------------------------------------------
# BEST = REPURPOSE   (lowest dead-zone cash burn = deficit + reactivation, all constraints held)
#
#   * REPURPOSE is not a cost configuration. It runs the SMALL_FORMAT cost base but
#     fills 48.6% from adjacent non-student catchment (471-569 orders/day); feasible only where the site clears the >=513/day filter.
#     Cost levers alone take the requirement from 70.8% to 48.6% of term volume and
#     CANNOT close it - residual campus population supplies only 8-15%. The demand-
#     side repurpose is the majority of the answer, and D1's largest problem is then
#     solved by D2's site filter rather than by an operating lever.
#
# ------------------------------------------------------------------------------------
# READ-OUT
# ------------------------------------------------------------------------------------
#   Cost ladder cuts the dead-zone deficit from Rs31.6L (DO_NOTHING) to Rs18.5L (SMALL_FORMAT),
#   a 41% reduction, at the price of a 28-day reactivation lead and Rs2.7L of rehire /
#   cold pull-down / rider re-acquisition opex. REPURPOSE takes the deficit to zero.
#
# ================================================================================
#              PARAMETER PROVENANCE  (no value typed into this file)
# ================================================================================
#   break configurations (4)       break_mode.CONFIGS
#   break-mode P&L / deficit       break_mode.break_monthly_cm
#   residual-demand thresholds     break_mode.threshold(cfg_*)
#   reactivation opex              break_mode.reactivation
#   adjacent-catchment sizing      break_mode.adjacent_catchment_required
#   small-format rent saving       break_mode.RENT_SAVED (<- rent_lever, cost_stack)
#   cold right-size saving         break_mode.cfg_cold (<- cost_stack.COLD_KW/COLD_HRS/TARIFF)
#   campus AOV / CM per order      break_mode.CAMPUS_AOV / cm_order (<- cost_stack.breakeven_d2_consistent)
#   reactivation lead time         risk_quadrant.RAMP_DAYS (= break_mode playbook T-28d)
#   SLA at peak                    sla.sla_minutes at 4x BASE_RATE
#   revocation catchment floor     risk_quadrant.post_revocation_survival
#   7-week wind-down rule          risk_quadrant.MIN_WEEKS
# CompletedProcess(args=['/Library/Developer/CommandLineTools/usr/bin/python3', 'Model/solver.py'], returncode=0)

# %% [markdown]
# ## How to read the result
#
# Compare the five strategies on dead-zone cost, residual-demand threshold, reactivation cost, lead time, and constraint feasibility.
#
# The optimum is conditional on the sourced inputs and encoded constraints; changing them can change the selected strategy.
