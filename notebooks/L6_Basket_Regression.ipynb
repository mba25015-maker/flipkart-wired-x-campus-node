# %%
# %cd /content
# !test -d flipkart-wired-x-campus-node/.git || git clone -q https://github.com/mba25015-maker/flipkart-wired-x-campus-node.git
# !git -C flipkart-wired-x-campus-node pull -q
# %cd /content/flipkart-wired-x-campus-node
# !pip -q install -r requirements.txt

# %% [markdown]
# ## What this notebook proves
#
# This notebook reproduces the four-quarter relationship between non-grocery mix and basket value.
#
# It shows the fitted slope, intercept, R-squared, and the share needed after the term-start occasion lift.
#
# Expected headline result: **R-squared = 0.918.**

# %%
# !python3 Model/basket.py

# %% [markdown]
# ## Important limitation
#
# The regression is estimated using only four quarterly observations. The reported R-squared describes in-sample fit within a very small sample and should not be interpreted as strong out-of-sample validation.
